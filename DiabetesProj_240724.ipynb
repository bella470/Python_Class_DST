# %% [markdown]
# <a href="https://colab.research.google.com/github/bella470/Python_Class_DST/blob/main/DiabetesProj_240724.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('/content/diabetes.csv')
df.head(100)
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             6      148             72             35        0  33.6
# 1             1       85             66             29        0  26.6
# 2             8      183             64              0        0  23.3
# 3             1       89             66             23       94  28.1
# 4             0      137             40             35      168  43.1
# ..          ...      ...            ...            ...      ...   ...
# 95            6      144             72             27      228  33.9
# 96            2       92             62             28        0  31.6
# 97            1       71             48             18       76  20.4
# 98            6       93             50             30       64  28.7
# 99            1      122             90             51      220  49.7
#
#     DiabetesPedigreeFunction  Age  Outcome
# 0                      0.627   50        1
# ...

# %%
df.shape
# Out:
# (768, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# Have 0 value for some column and include it as data

# %%
df['BMI'].value_counts()
# Out:
# BMI
# 32.0    13
# 31.6    12
# 31.2    12
# 0.0     11
# 32.4    10
#         ..
# 36.7     1
# 41.8     1
# 42.6     1
# 42.8     1
# 46.3     1
# Name: count, Length: 248, dtype: int64

# %%
df['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %% [markdown]
# Normalize data
#
# - Column chosen to normalize (Pregnancies	Glucose	BloodPressure	SkinThickness	Insulin	BMI Age)
#
# - Decide to use simple feature scalling

# %%
#use simple feature scalling to normalize data with huge gap

df['Pregnancies'] = df['Pregnancies'] / df['Pregnancies'].max()

df['Glucose'] = df['Glucose'] / df['Glucose'].max()

df['BloodPressure'] = df['BloodPressure'] / df['BloodPressure'].max()

df['SkinThickness'] = df['SkinThickness'] / df['SkinThickness'].max()

df['Insulin'] = df['Insulin'] / df['Insulin'].max()

df['BMI'] = df['BMI'] / df['BMI'].max()

df['Age'] = df['Age'] / df['Age'].max()

df[['Pregnancies', 'Glucose',	'BloodPressure',	'SkinThickness',	'Insulin',	'BMI', 'Age']].head()
# Out:
#    Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0     0.352941  0.743719       0.590164       0.353535  0.000000  0.500745
# 1     0.058824  0.427136       0.540984       0.292929  0.000000  0.396423
# 2     0.470588  0.919598       0.524590       0.000000  0.000000  0.347243
# 3     0.058824  0.447236       0.540984       0.232323  0.111111  0.418778
# 4     0.000000  0.688442       0.327869       0.353535  0.198582  0.642325
#
#         Age
# 0  0.617284
# 1  0.382716
# 2  0.395062
# 3  0.259259
# 4  0.407407

# %%
df.head(20)
# Out:
#     Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0      0.352941  0.743719       0.590164       0.353535  0.000000  0.500745
# 1      0.058824  0.427136       0.540984       0.292929  0.000000  0.396423
# 2      0.470588  0.919598       0.524590       0.000000  0.000000  0.347243
# 3      0.058824  0.447236       0.540984       0.232323  0.111111  0.418778
# 4      0.000000  0.688442       0.327869       0.353535  0.198582  0.642325
# 5      0.294118  0.582915       0.606557       0.000000  0.000000  0.381520
# 6      0.176471  0.391960       0.409836       0.323232  0.104019  0.461997
# 7      0.588235  0.577889       0.000000       0.000000  0.000000  0.526080
# 8      0.117647  0.989950       0.573770       0.454545  0.641844  0.454545
# 9      0.470588  0.628141       0.786885       0.000000  0.000000  0.000000
# 10     0.235294  0.552764       0.754098       0.000000  0.000000  0.560358
# ...

# %%
#most positive correlation
correlations = df.corr()

correlations['Outcome'].sort_values(ascending=False)
# Out:
# Outcome                     1.000000
# Glucose                     0.466581
# BMI                         0.292695
# Age                         0.238356
# Pregnancies                 0.221898
# DiabetesPedigreeFunction    0.173844
# Insulin                     0.130548
# SkinThickness               0.074752
# BloodPressure               0.065068
# Name: Outcome, dtype: float64

# %% [markdown]
# **KNN method**

# %%
X = df.iloc[:, :-1].values
y = df['Outcome'].values

# %%
#split train and test set

from sklearn.model_selection import train_test_split

# once random_state activated even =0, it will reshuffle the datasets
#Funfact: 42 is the number of a US movie many years ago, that's why it used here
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=1)

print('Train set:', X_train.shape, y_train.shape)
print('Test set:', X_test.shape, y_test.shape)
# Out:
# Train set: (576, 8) (576,)
# Test set: (192, 8) (192,)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

#should be integer
#have default value if not mention
neigh = KNeighborsClassifier()

#training
neigh.fit(X_train, y_train)

#prediction
y_hat = neigh.predict(X_test)

#evaluate
#use accuracy score, it compare actual result and predicted result
print('The accuracy of the model is: ', (accuracy_score(y_test, y_hat))*100)
# Out:
# The accuracy of the model is:  75.52083333333334

# %%
import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np

Ks = 20
mean_acc = np.zeros((Ks-1))
std_acc = np.zeros((Ks-1))
ConfustionMx = [];
for n in range(1,Ks):

    #Train Model and Predict
    neigh = KNeighborsClassifier(n_neighbors = n).fit(X_train,y_train)
    yhat=neigh.predict(X_test)
    mean_acc[n-1] = metrics.accuracy_score(y_test, yhat)


    std_acc[n-1]=np.std(yhat==y_test)/np.sqrt(yhat.shape[0])

#print (mean_acc)

print ('')
print ('')

plt.plot(range(1,Ks),mean_acc,'g')
plt.fill_between(range(1,Ks),mean_acc - 1 * std_acc,mean_acc + 1 * std_acc, alpha=0.10)
plt.legend(('Accuracy ', '+/- 3xstd'))
plt.ylabel('Accuracy ')
plt.xlabel('The Value of NN (K)')
plt.tight_layout()
plt.show()

print ('')
print ('')

print( "The best accuracy was with", mean_acc.max(), "with k=", mean_acc.argmax()+1)
# Out:
# The best accuracy was with 0.7916666666666666 with k= 11

# %% [markdown]
# Use column with high correlation only

# %%
X1 = df[['Glucose','BMI','Age','Pregnancies','DiabetesPedigreeFunction','Insulin','SkinThickness']]

X1.head()
# Out:
#     Glucose       BMI       Age  Pregnancies  DiabetesPedigreeFunction  \
# 0  0.743719  0.500745  0.617284     0.352941                     0.627
# 1  0.427136  0.396423  0.382716     0.058824                     0.351
# 2  0.919598  0.347243  0.395062     0.470588                     0.672
# 3  0.447236  0.418778  0.259259     0.058824                     0.167
# 4  0.688442  0.642325  0.407407     0.000000                     2.288
#
#     Insulin  SkinThickness
# 0  0.000000       0.353535
# 1  0.000000       0.292929
# 2  0.000000       0.000000
# 3  0.111111       0.232323
# 4  0.198582       0.353535

# %%
X1 = df[['Glucose','BMI','Age','Pregnancies','DiabetesPedigreeFunction','Insulin','SkinThickness']].values
y1 = df['Outcome'].values

# %%
#split train and test set

from sklearn.model_selection import train_test_split

# once random_state activated even =0, it will reshuffle the datasets
#Funfact: 42 is the number of a US movie many years ago, that's why it used here
X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, test_size=0.20, random_state=1)

print('Train set:', X1_train.shape, y1_train.shape)
print('Test set:', X1_test.shape, y1_test.shape)
# Out:
# Train set: (614, 7) (614,)
# Test set: (154, 7) (154,)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

#should be integer
#have default value if not mention
neigh1 = KNeighborsClassifier()

#training
neigh1.fit(X1_train, y1_train)

#prediction
y1_hat = neigh1.predict(X1_test)

#evaluate
#use accuracy score, it compare actual result and predicted result
print('The accuracy of the model is: ', (accuracy_score(y1_test, y1_hat))*100)
# Out:
# The accuracy of the model is:  77.92207792207793

# %%
import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np

Ks = 20
mean_acc = np.zeros((Ks-1))
std_acc = np.zeros((Ks-1))
ConfustionMx = [];
for n in range(1,Ks):

    #Train Model and Predict
    neigh1 = KNeighborsClassifier(n_neighbors = n).fit(X1_train,y1_train)
    y1hat=neigh1.predict(X1_test)
    mean_acc[n-1] = metrics.accuracy_score(y1_test, y1hat)


    std_acc[n-1]=np.std(y1hat==y1_test)/np.sqrt(y1hat.shape[0])

#print (mean_acc)

print ('')
print ('')

plt.plot(range(1,Ks),mean_acc,'g')
plt.fill_between(range(1,Ks),mean_acc - 1 * std_acc,mean_acc + 1 * std_acc, alpha=0.10)
plt.legend(('Accuracy ', '+/- 3xstd'))
plt.ylabel('Accuracy ')
plt.xlabel('The Value of NN (K)')
plt.tight_layout()
plt.show()

print ('')
print ('')

print( "The best accuracy was with", mean_acc.max(), "with k=", mean_acc.argmax()+1)
# Out:
# The best accuracy was with 0.7987012987012987 with k= 15

# %% [markdown]
# **Decision Tree Method**

# %%
X2 = df[['Glucose','BMI','Age','Pregnancies','DiabetesPedigreeFunction','Insulin','SkinThickness']].values
y2 = df['Outcome'].values

# %%
from sklearn.model_selection import train_test_split

X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2, test_size=0.25, random_state=1)

X2_train.shape
# Out:
# (576, 7)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import jaccard_score

DS = DecisionTreeClassifier()

#fit # training
DS.fit(X1_train, y1_train)

#predict
y1_hat = DS.predict(X1_test)

#evaluate
print('The accuracy score is: ', accuracy_score(y1_test, y1_hat))
print('')
print('The CM is: ', confusion_matrix(y1_test, y1_hat))
print('')
print('The JS is: ', jaccard_score(y1_test, y1_hat, average = 'micro')) #average is the class
# Out:
# The accuracy score is:  0.6883116883116883
#
# The CM is:  [[79 20]
#  [28 27]]
#
# The JS is:  0.5247524752475248
