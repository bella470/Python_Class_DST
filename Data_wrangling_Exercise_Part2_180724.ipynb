# %% [markdown]
# <a href="https://colab.research.google.com/github/bella470/Python_Class_DST/blob/main/Data_wrangling_Exercise_Part2_180724.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

#can copy path from the file
exdata= pd.read_csv('NHANES.csv')

exdata.head(10)
#the first row data take as the header
# Out:
#     SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 0  83732     1.0     NaN     1.0       1         1        62         3
# 1  83733     1.0     NaN     6.0       1         1        53         3
# 2  83734     1.0     NaN     NaN       1         1        78         3
# 3  83735     2.0     1.0     1.0       2         2        56         3
# 4  83736     2.0     1.0     1.0       2         2        42         4
# 5  83737     2.0     2.0     NaN       2         2        72         1
# 6  83741     1.0     NaN     8.0       1         1        22         4
# 7  83742     1.0     NaN     1.0       2         2        32         1
# 8  83743     NaN     NaN     NaN       2         1        18         5
# 9  83744     1.0     NaN     NaN       2         1        56         4
#
#    DMDCITZN  DMDEDUC2  ...  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# 0       1.0       5.0  ...   124.0    64.0   94.8  184.5    27.8    43.3
# ...

# %%
exdata.shape
# Out:
# (5735, 28)

# %%
exdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5735 entries, 0 to 5734
# Data columns (total 28 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SEQN      5735 non-null   int64
#  1   ALQ101    5208 non-null   float64
#  2   ALQ110    1731 non-null   float64
#  3   ALQ130    3379 non-null   float64
#  4   SMQ020    5735 non-null   int64
#  5   RIAGENDR  5735 non-null   int64
#  6   RIDAGEYR  5735 non-null   int64
#  7   RIDRETH1  5735 non-null   int64
#  8   DMDCITZN  5734 non-null   float64
#  9   DMDEDUC2  5474 non-null   float64
#  10  DMDMARTL  5474 non-null   float64
#  11  DMDHHSIZ  5735 non-null   int64
#  12  WTINT2YR  5735 non-null   float64
#  13  SDMVPSU   5735 non-null   int64
#  14  SDMVSTRA  5735 non-null   int64
#  15  INDFMPIR  5134 non-null   float64
#  16  BPXSY1    5401 non-null   float64
#  17  BPXDI1    5401 non-null   float64
#  18  BPXSY2    5535 non-null   float64
#  19  BPXDI2    5535 non-null   float64
# ...

# %% [markdown]
# **Handling Missing Value**
#
# - If missing value is more than 30% from the original data, just leave it or drop it

# %%
exdata.describe(include = 'all')
# Out:
#                SEQN       ALQ101       ALQ110       ALQ130       SMQ020  \
# count   5735.000000  5208.000000  1731.000000  3379.000000  5735.000000
# mean   88678.583435     1.336406     1.587522     3.911512     1.607149
# std     2882.139237     0.505514     0.623940    34.341839     0.571975
# min    83732.000000     1.000000     1.000000     1.000000     1.000000
# 25%    86164.000000     1.000000     1.000000     1.000000     1.000000
# 50%    88668.000000     1.000000     2.000000     2.000000     2.000000
# 75%    91178.500000     2.000000     2.000000     3.000000     2.000000
# max    93702.000000     9.000000     9.000000   999.000000     9.000000
#
#           RIAGENDR     RIDAGEYR     RIDRETH1     DMDCITZN     DMDEDUC2  ...  \
# count  5735.000000  5735.000000  5735.000000  5734.000000  5474.000000  ...
# mean      1.518919    48.052310     3.042371     1.185385     3.441725  ...
# std       0.499686    18.431011     1.296793     0.491678     1.309700  ...
# ...

# %%
#displaying all the columns

pd.set_option ('display.max_columns', None)

exdata.head(10)
# Out:
#     SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 0  83732     1.0     NaN     1.0       1         1        62         3
# 1  83733     1.0     NaN     6.0       1         1        53         3
# 2  83734     1.0     NaN     NaN       1         1        78         3
# 3  83735     2.0     1.0     1.0       2         2        56         3
# 4  83736     2.0     1.0     1.0       2         2        42         4
# 5  83737     2.0     2.0     NaN       2         2        72         1
# 6  83741     1.0     NaN     8.0       1         1        22         4
# 7  83742     1.0     NaN     1.0       2         2        32         1
# 8  83743     NaN     NaN     NaN       2         1        18         5
# 9  83744     1.0     NaN     NaN       2         1        56         4
#
#    DMDCITZN  DMDEDUC2  DMDMARTL  DMDHHSIZ   WTINT2YR  SDMVPSU  SDMVSTRA  \
# 0       1.0       5.0       1.0         2  134671.37        1       125
# ...

# %%
exdata.isnull()
# Out:
#        SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 0     False   False    True   False   False     False     False     False
# 1     False   False    True   False   False     False     False     False
# 2     False   False    True    True   False     False     False     False
# 3     False   False   False   False   False     False     False     False
# 4     False   False   False   False   False     False     False     False
# ...     ...     ...     ...     ...     ...       ...       ...       ...
# 5730  False   False   False    True   False     False     False     False
# 5731  False   False   False    True   False     False     False     False
# 5732  False   False    True   False   False     False     False     False
# 5733  False    True    True    True   False     False     False     False
# 5734  False   False    True   False   False     False     False     False
#
#       DMDCITZN  DMDEDUC2  DMDMARTL  DMDHHSIZ  WTINT2YR  SDMVPSU  SDMVSTRA  \
# ...

# %%
exdata.isnull().sum()
# Out:
# SEQN           0
# ALQ101       527
# ALQ110      4004
# ALQ130      2356
# SMQ020         0
# RIAGENDR       0
# RIDAGEYR       0
# RIDRETH1       0
# DMDCITZN       1
# DMDEDUC2     261
# DMDMARTL     261
# DMDHHSIZ       0
# WTINT2YR       0
# SDMVPSU        0
# SDMVSTRA       0
# INDFMPIR     601
# BPXSY1       334
# BPXDI1       334
# BPXSY2       200
# BPXDI2       200
# BMXWT         69
# BMXHT         62
# BMXBMI        73
# BMXLEG       390
# BMXARML      308
# BMXARMC      308
# BMXWAIST     367
# HIQ210      1003
# dtype: int64

# %% [markdown]
# ### **Columns with missing values:**
#
# ALQ101: 527
#
# ALQ110: 4004
#
# ALQ130: 2356
#
# DMDCITZN: 1
#
# DMDEDUC2: 261
#
# DMDMARTL: 261
#
# INDFMPIR: 601
#
# BPXSY1: 334
#
# BPXDI1: 334
#
# BPXSY2: 200
#
# BPXDI2: 200
#
# BMXWT: 69
#
# BMXHT: 62
#
# BMXBMI: 73
#
# BMXLEG: 390
#
# BMXARML: 308
#
# BMXARMC: 308
#
# BMXWAIST: 367
#
# HIQ210: 1003

# %%
mean_alq101 = exdata['ALQ101'].astype('float').mean()

mean_alq101
# Out:
# 1.336405529953917

# %%
import numpy as np

exdata['ALQ101'].replace(np.nan, mean_alq101, inplace = True)

exdata.isnull().sum()
# Out:
# SEQN           0
# ALQ101         0
# ALQ110      4004
# ALQ130      2356
# SMQ020         0
# RIAGENDR       0
# RIDAGEYR       0
# RIDRETH1       0
# DMDCITZN       1
# DMDEDUC2     261
# DMDMARTL     261
# DMDHHSIZ       0
# WTINT2YR       0
# SDMVPSU        0
# SDMVSTRA       0
# INDFMPIR     601
# BPXSY1       334
# BPXDI1       334
# BPXSY2       200
# BPXDI2       200
# BMXWT         69
# BMXHT         62
# BMXBMI        73
# BMXLEG       390
# BMXARML      308
# BMXARMC      308
# BMXWAIST     367
# HIQ210      1003
# dtype: int64

# %%
mean_alq110 = exdata['ALQ110'].astype('float').mean()

mean_alq110
# Out:
# 1.5875216637781628

# %%
exdata['ALQ110'].replace(np.nan, mean_alq110, inplace = True)

exdata.isnull().sum()
# Out:
# SEQN           0
# ALQ101         0
# ALQ110         0
# ALQ130      2356
# SMQ020         0
# RIAGENDR       0
# RIDAGEYR       0
# RIDRETH1       0
# DMDCITZN       1
# DMDEDUC2     261
# DMDMARTL     261
# DMDHHSIZ       0
# WTINT2YR       0
# SDMVPSU        0
# SDMVSTRA       0
# INDFMPIR     601
# BPXSY1       334
# BPXDI1       334
# BPXSY2       200
# BPXDI2       200
# BMXWT         69
# BMXHT         62
# BMXBMI        73
# BMXLEG       390
# BMXARML      308
# BMXARMC      308
# BMXWAIST     367
# HIQ210      1003
# dtype: int64

# %%
mean_alq130 = exdata['ALQ130'].astype('float').mean()

mean_alq130
# Out:
# 3.9115122817401597

# %%
exdata['ALQ130'].replace(np.nan, mean_alq130, inplace = True)

exdata.isnull().sum()
# Out:
# SEQN           0
# ALQ101         0
# ALQ110         0
# ALQ130         0
# SMQ020         0
# RIAGENDR       0
# RIDAGEYR       0
# RIDRETH1       0
# DMDCITZN       1
# DMDEDUC2     261
# DMDMARTL     261
# DMDHHSIZ       0
# WTINT2YR       0
# SDMVPSU        0
# SDMVSTRA       0
# INDFMPIR     601
# BPXSY1       334
# BPXDI1       334
# BPXSY2       200
# BPXDI2       200
# BMXWT         69
# BMXHT         62
# BMXBMI        73
# BMXLEG       390
# BMXARML      308
# BMXARMC      308
# BMXWAIST     367
# HIQ210      1003
# dtype: int64

# %%
mean_dmdcitzn = exdata['DMDCITZN'].astype('float').mean()

exdata['DMDCITZN'].replace(np.nan, mean_dmdcitzn, inplace = True)

exdata.isnull().sum()
# Out:
# SEQN           0
# ALQ101         0
# ALQ110         0
# ALQ130         0
# SMQ020         0
# RIAGENDR       0
# RIDAGEYR       0
# RIDRETH1       0
# DMDCITZN       0
# DMDEDUC2     261
# DMDMARTL     261
# DMDHHSIZ       0
# WTINT2YR       0
# SDMVPSU        0
# SDMVSTRA       0
# INDFMPIR     601
# BPXSY1       334
# BPXDI1       334
# BPXSY2       200
# BPXDI2       200
# BMXWT         69
# BMXHT         62
# BMXBMI        73
# BMXLEG       390
# BMXARML      308
# BMXARMC      308
# BMXWAIST     367
# HIQ210      1003
# dtype: int64

# %%
mean_dmdeduc2 = exdata['DMDEDUC2'].astype('float').mean()

exdata['DMDEDUC2'].replace(np.nan, mean_dmdeduc2, inplace = True)

exdata.isnull().sum()
# Out:
# SEQN           0
# ALQ101         0
# ALQ110         0
# ALQ130         0
# SMQ020         0
# RIAGENDR       0
# RIDAGEYR       0
# RIDRETH1       0
# DMDCITZN       0
# DMDEDUC2       0
# DMDMARTL     261
# DMDHHSIZ       0
# WTINT2YR       0
# SDMVPSU        0
# SDMVSTRA       0
# INDFMPIR     601
# BPXSY1       334
# BPXDI1       334
# BPXSY2       200
# BPXDI2       200
# BMXWT         69
# BMXHT         62
# BMXBMI        73
# BMXLEG       390
# BMXARML      308
# BMXARMC      308
# BMXWAIST     367
# HIQ210      1003
# dtype: int64

# %%
mean_dmdmartl = exdata['DMDMARTL'].astype('float').mean()

exdata['DMDMARTL'].replace(np.nan, mean_dmdmartl, inplace = True)

exdata.isnull().sum()
# Out:
# SEQN           0
# ALQ101         0
# ALQ110         0
# ALQ130         0
# SMQ020         0
# RIAGENDR       0
# RIDAGEYR       0
# RIDRETH1       0
# DMDCITZN       0
# DMDEDUC2       0
# DMDMARTL       0
# DMDHHSIZ       0
# WTINT2YR       0
# SDMVPSU        0
# SDMVSTRA       0
# INDFMPIR     601
# BPXSY1       334
# BPXDI1       334
# BPXSY2       200
# BPXDI2       200
# BMXWT         69
# BMXHT         62
# BMXBMI        73
# BMXLEG       390
# BMXARML      308
# BMXARMC      308
# BMXWAIST     367
# HIQ210      1003
# dtype: int64

# %%
mean_indfmpir = exdata['INDFMPIR'].astype('float').mean()

exdata['INDFMPIR'].replace(np.nan, mean_indfmpir, inplace = True)

mean_bpxsy1 = exdata['BPXSY1'].astype('float').mean()

exdata['BPXSY1'].replace(np.nan, mean_bpxsy1, inplace = True)

mean_bpxdi1 = exdata['BPXDI1'].astype('float').mean()

exdata['BPXDI1'].replace(np.nan, mean_bpxdi1, inplace = True)

exdata.isnull().sum()
# Out:
# SEQN           0
# ALQ101         0
# ALQ110         0
# ALQ130         0
# SMQ020         0
# RIAGENDR       0
# RIDAGEYR       0
# RIDRETH1       0
# DMDCITZN       0
# DMDEDUC2       0
# DMDMARTL       0
# DMDHHSIZ       0
# WTINT2YR       0
# SDMVPSU        0
# SDMVSTRA       0
# INDFMPIR       0
# BPXSY1         0
# BPXDI1         0
# BPXSY2       200
# BPXDI2       200
# BMXWT         69
# BMXHT         62
# BMXBMI        73
# BMXLEG       390
# BMXARML      308
# BMXARMC      308
# BMXWAIST     367
# HIQ210      1003
# dtype: int64

# %%
mean_bpxsy2 = exdata['BPXSY2'].astype('float').mean()

exdata['BPXSY2'].replace(np.nan, mean_bpxsy2, inplace = True)

mean_bpxdi2 = exdata['BPXDI2'].astype('float').mean()

exdata['BPXDI2'].replace(np.nan, mean_bpxdi2, inplace = True)

mean_bmxwt = exdata['BMXWT'].astype('float').mean()

exdata['BMXWT'].replace(np.nan, mean_bmxwt, inplace = True)

mean_bmxht = exdata['BMXHT'].astype('float').mean()

exdata['BMXHT'].replace(np.nan, mean_bmxht, inplace = True)

mean_bmxbmi = exdata['BMXBMI'].astype('float').mean()

exdata['BMXBMI'].replace(np.nan, mean_bmxbmi, inplace = True)

mean_bmxleg = exdata['BMXLEG'].astype('float').mean()

exdata['BMXLEG'].replace(np.nan, mean_bmxleg, inplace = True)

exdata.isnull().sum()
# Out:
# SEQN           0
# ALQ101         0
# ALQ110         0
# ALQ130         0
# SMQ020         0
# RIAGENDR       0
# RIDAGEYR       0
# RIDRETH1       0
# DMDCITZN       0
# DMDEDUC2       0
# DMDMARTL       0
# DMDHHSIZ       0
# WTINT2YR       0
# SDMVPSU        0
# SDMVSTRA       0
# INDFMPIR       0
# BPXSY1         0
# BPXDI1         0
# BPXSY2         0
# BPXDI2         0
# BMXWT          0
# BMXHT          0
# BMXBMI         0
# BMXLEG         0
# BMXARML      308
# BMXARMC      308
# BMXWAIST     367
# HIQ210      1003
# dtype: int64

# %%
mean_bmxarml = exdata['BMXARML'].astype('float').mean()

exdata['BMXARML'].replace(np.nan, mean_bmxarml, inplace = True)

mean_bmxarmc = exdata['BMXARMC'].astype('float').mean()

exdata['BMXARMC'].replace(np.nan, mean_bmxarmc, inplace = True)

mean_bmxwaist = exdata['BMXWAIST'].astype('float').mean()

exdata['BMXWAIST'].replace(np.nan, mean_bmxwaist, inplace = True)

mean_hiq210 = exdata['HIQ210'].astype('float').mean()

exdata['HIQ210'].replace(np.nan, mean_hiq210, inplace = True)

exdata.isnull().sum()
# Out:
# SEQN        0
# ALQ101      0
# ALQ110      0
# ALQ130      0
# SMQ020      0
# RIAGENDR    0
# RIDAGEYR    0
# RIDRETH1    0
# DMDCITZN    0
# DMDEDUC2    0
# DMDMARTL    0
# DMDHHSIZ    0
# WTINT2YR    0
# SDMVPSU     0
# SDMVSTRA    0
# INDFMPIR    0
# BPXSY1      0
# BPXDI1      0
# BPXSY2      0
# BPXDI2      0
# BMXWT       0
# BMXHT       0
# BMXBMI      0
# BMXLEG      0
# BMXARML     0
# BMXARMC     0
# BMXWAIST    0
# HIQ210      0
# dtype: int64

# %% [markdown]
# **Data Formatting**

# %%
exdata.dtypes
# Out:
# SEQN          int64
# ALQ101      float64
# ALQ110      float64
# ALQ130      float64
# SMQ020        int64
# RIAGENDR      int64
# RIDAGEYR      int64
# RIDRETH1      int64
# DMDCITZN    float64
# DMDEDUC2    float64
# DMDMARTL    float64
# DMDHHSIZ      int64
# WTINT2YR    float64
# SDMVPSU       int64
# SDMVSTRA      int64
# INDFMPIR    float64
# BPXSY1      float64
# BPXDI1      float64
# BPXSY2      float64
# BPXDI2      float64
# BMXWT       float64
# BMXHT       float64
# BMXBMI      float64
# BMXLEG      float64
# BMXARML     float64
# BMXARMC     float64
# BMXWAIST    float64
# HIQ210      float64
# dtype: object

# %%
exdata.head()
# Out:
#     SEQN  ALQ101    ALQ110    ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 0  83732     1.0  1.587522  1.000000       1         1        62         3
# 1  83733     1.0  1.587522  6.000000       1         1        53         3
# 2  83734     1.0  1.587522  3.911512       1         1        78         3
# 3  83735     2.0  1.000000  1.000000       2         2        56         3
# 4  83736     2.0  1.000000  1.000000       2         2        42         4
#
#    DMDCITZN  DMDEDUC2  DMDMARTL  DMDHHSIZ   WTINT2YR  SDMVPSU  SDMVSTRA  \
# 0       1.0       5.0       1.0         2  134671.37        1       125
# 1       2.0       3.0       3.0         1   24328.56        1       125
# 2       1.0       3.0       1.0         2   12400.01        1       131
# 3       1.0       5.0       6.0         1  102718.00        1       131
# 4       1.0       4.0       3.0         5   17627.67        2       126
#
#    INDFMPIR  BPXSY1  BPXDI1  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# ...

# %% [markdown]
# **Data Normalization**

# %%
exdata.describe()
# Out:
#                SEQN       ALQ101       ALQ110       ALQ130       SMQ020  \
# count   5735.000000  5735.000000  5735.000000  5735.000000  5735.000000
# mean   88678.583435     1.336406     1.587522     3.911512     1.607149
# std     2882.139237     0.481723     0.342718    26.358733     0.571975
# min    83732.000000     1.000000     1.000000     1.000000     1.000000
# 25%    86164.000000     1.000000     1.587522     2.000000     1.000000
# 50%    88668.000000     1.000000     1.587522     3.911512     2.000000
# 75%    91178.500000     2.000000     1.587522     3.911512     2.000000
# max    93702.000000     9.000000     9.000000   999.000000     9.000000
#
#           RIAGENDR     RIDAGEYR     RIDRETH1     DMDCITZN     DMDEDUC2  \
# count  5735.000000  5735.000000  5735.000000  5735.000000  5735.000000
# mean      1.518919    48.052310     3.042371     1.185385     3.441725
# std       0.499686    18.431011     1.296793     0.491635     1.279545
# ...

# %% [markdown]
# **Columns that need to be normalize:**
# 1.   ALQ130 *
#
# 2.   RIDAGEYR
#
# 3.   DMDMARTL
#
# 4.   WTINT2YR *
#
# 5.   SDMVSTRA
#
# 6.   BPXSY1 *
#
# 7.   BPXDI1
#
# 8.   BPXSY2
#
# 9.   BPXDI2
#
# 10.  BMXWT
#
# 11.  BMXHT
#
# 12.  BMXWAIST

# %%
exdata[['ALQ130', 'WTINT2YR', 'BPXSY1']].head(10)
# Out:
#      ALQ130   WTINT2YR      BPXSY1
# 0  1.000000  134671.37  128.000000
# 1  6.000000   24328.56  146.000000
# 2  3.911512   12400.01  138.000000
# 3  1.000000  102718.00  132.000000
# 4  1.000000   17627.67  100.000000
# 5  3.911512   11252.31  116.000000
# 6  8.000000   37043.09  110.000000
# 7  1.000000   22744.36  120.000000
# 8  3.911512   18526.16  125.084614
# 9  3.911512   20395.54  178.000000

# %%
#method 1: Simple Feature Scalling

exdata['ALQ130'] = exdata['ALQ130'] / exdata['ALQ130'].max()

exdata['WTINT2YR'] = exdata['WTINT2YR'] / exdata['WTINT2YR'].max()

exdata['BPXSY1'] = exdata['BPXSY1'] / exdata['BPXSY1'].max()

exdata[['ALQ130', 'WTINT2YR', 'BPXSY1']].head()
# Out:
#      ALQ130  WTINT2YR    BPXSY1
# 0  0.001001  0.576120  0.542373
# 1  0.006006  0.104077  0.618644
# 2  0.003915  0.053047  0.584746
# 3  0.001001  0.439424  0.559322
# 4  0.001001  0.075411  0.423729

# %%
exdata[['ALQ130', 'WTINT2YR', 'BPXSY1']].describe()
# Out:
#             ALQ130     WTINT2YR       BPXSY1
# count  5735.000000  5735.000000  5735.000000
# mean      0.003915     0.172455     0.530020
# std       0.026385     0.165852     0.075994
# min       0.001001     0.022806     0.347458
# 25%       0.002002     0.073427     0.483051
# 50%       0.003915     0.105473     0.525424
# 75%       0.003915     0.183364     0.567797
# max       1.000000     1.000000     1.000000
